# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,89,2000)
lngs = np.random.uniform(-90,89,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wind_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wind_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | manicore
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | burlatskoye
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 1 | hambantota
# Processing Record 9 of Set 1 | sao geraldo do araguaia
# Processing Record 10 of Set 1 | van
# Processing Record 11 of Set 1 | juba
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | oriximina
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | kostomuksha
# Processing Record 16 of Set 1 | gondomar
# Processing Record 17 of Set 1 | pamyat parizhskoy kommuny
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | edd
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | zhezkazgan
# Processing Record 23 of Set 1 | pitimbu
# Processing Record 24 of Set 1 | barbastro
# Processing Record 25 of Set 1 | saint-nazaire
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | vardo
# Processing Record 28 of Set 1 | mazara del vallo
# Processing Record 29 of Set 1 | margate
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | bahar
# Processing Record 34 of Set 1 | maceio
# Processing Record 35 of Set 1 | gamba
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | varkaus
# Processing Record 38 of Set 1 | aasiaat
# Processing Record 39 of Set 1 | arrecife
# Processing Record 40 of Set 1 | otanche
# Processing Record 41 of Set 1 | cuxhaven
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | novorzhev
# Processing Record 46 of Set 1 | abha
# Processing Record 47 of Set 1 | lasa
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | rorvik
# Processing Record 50 of Set 1 | goundam
# Processing Record 1 of Set 2 | de aar
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | jalu
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | kombotion
# City not found. Skipping...
# Processing Record 6 of Set 2 | vestmanna
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | gewane
# Processing Record 9 of Set 2 | bayan
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | piacabucu
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | nuuk
# Processing Record 15 of Set 2 | marv dasht
# City not found. Skipping...
# Processing Record 16 of Set 2 | shelburne
# Processing Record 17 of Set 2 | coihaique
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | cornelio procopio
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | bam
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | buchanan
# Processing Record 24 of Set 2 | lunenburg
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | porto walter
# Processing Record 30 of Set 2 | comodoro rivadavia
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | wellington
# Processing Record 33 of Set 2 | san ramon
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | nalut
# Processing Record 36 of Set 2 | paratinga
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | bartica
# Processing Record 42 of Set 2 | san rafael
# Processing Record 43 of Set 2 | belmonte
# Processing Record 44 of Set 2 | goderich
# Processing Record 45 of Set 2 | ondjiva
# Processing Record 46 of Set 2 | brae
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | antalaha
# Processing Record 49 of Set 2 | luderitz
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | atar
# Processing Record 3 of Set 3 | tortoli
# Processing Record 4 of Set 3 | samfya
# Processing Record 5 of Set 3 | hammerfest
# Processing Record 6 of Set 3 | sayyan
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | yusva
# City not found. Skipping...
# Processing Record 9 of Set 3 | dhidhdhoo
# Processing Record 10 of Set 3 | kapoeta
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | faya
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | sangin
# Processing Record 16 of Set 3 | belaguntha
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | platonovka
# Processing Record 19 of Set 3 | ouro preto do oeste
# Processing Record 20 of Set 3 | buraydah
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | fethiye
# Processing Record 23 of Set 3 | kuryk
# Processing Record 24 of Set 3 | noyabrsk
# Processing Record 25 of Set 3 | plotnikovo
# Processing Record 26 of Set 3 | obodivka
# Processing Record 27 of Set 3 | sao felix do xingu
# Processing Record 28 of Set 3 | dubenskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | qasigiannguit
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | dharmadam
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | marzuq
# Processing Record 37 of Set 3 | guapi
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | besancon
# Processing Record 40 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 3 | carnarvon
# Processing Record 42 of Set 3 | umm lajj
# Processing Record 43 of Set 3 | ponta delgada
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | halifax
# Processing Record 46 of Set 3 | henties bay
# Processing Record 47 of Set 3 | mehamn
# Processing Record 48 of Set 3 | kigoma
# Processing Record 49 of Set 3 | gorele
# Processing Record 50 of Set 3 | beaupre
# Processing Record 1 of Set 4 | chavakkad
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | birao
# Processing Record 4 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 4 | antofagasta
# Processing Record 6 of Set 4 | camopi
# Processing Record 7 of Set 4 | rabat
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | oak ridge
# Processing Record 10 of Set 4 | halkirk
# Processing Record 11 of Set 4 | kasane
# Processing Record 12 of Set 4 | envira
# Processing Record 13 of Set 4 | bajil
# Processing Record 14 of Set 4 | fershampenuaz
# Processing Record 15 of Set 4 | mogadouro
# Processing Record 16 of Set 4 | inongo
# Processing Record 17 of Set 4 | port-cartier
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | richards bay
# Processing Record 20 of Set 4 | warri
# Processing Record 21 of Set 4 | camacha
# Processing Record 22 of Set 4 | belyy yar
# Processing Record 23 of Set 4 | leh
# Processing Record 24 of Set 4 | uglich
# Processing Record 25 of Set 4 | barabinsk
# Processing Record 26 of Set 4 | campo verde
# Processing Record 27 of Set 4 | tatarsk
# Processing Record 28 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 4 | pombas
# Processing Record 30 of Set 4 | lagos
# Processing Record 31 of Set 4 | the valley
# Processing Record 32 of Set 4 | balkanabat
# Processing Record 33 of Set 4 | bad goisern
# Processing Record 34 of Set 4 | ostrovnoy
# Processing Record 35 of Set 4 | westerland
# Processing Record 36 of Set 4 | timra
# Processing Record 37 of Set 4 | behbahan
# Processing Record 38 of Set 4 | palasa
# Processing Record 39 of Set 4 | teguise
# Processing Record 40 of Set 4 | madimba
# Processing Record 41 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 4 | tazovskiy
# Processing Record 43 of Set 4 | walvis bay
# Processing Record 44 of Set 4 | carndonagh
# Processing Record 45 of Set 4 | muisne
# Processing Record 46 of Set 4 | asfi
# Processing Record 47 of Set 4 | lahij
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | maxixe
# Processing Record 50 of Set 4 | polkowice
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | grand gaube
# Processing Record 3 of Set 5 | struer
# Processing Record 4 of Set 5 | mao
# Processing Record 5 of Set 5 | gualaquiza
# Processing Record 6 of Set 5 | lucapa
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | svetlyy
# Processing Record 9 of Set 5 | joaima
# Processing Record 10 of Set 5 | bonthe
# Processing Record 11 of Set 5 | umm bab
# Processing Record 12 of Set 5 | ati
# Processing Record 13 of Set 5 | takoradi
# Processing Record 14 of Set 5 | khor
# Processing Record 15 of Set 5 | kudahuvadhoo
# Processing Record 16 of Set 5 | ponferrada
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 5 | kyabe
# Processing Record 20 of Set 5 | anapskaya
# Processing Record 21 of Set 5 | cetatea de balta
# City not found. Skipping...
# Processing Record 22 of Set 5 | marawi
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | friesach
# Processing Record 25 of Set 5 | sabha
# Processing Record 26 of Set 5 | saint anthony
# Processing Record 27 of Set 5 | tamandare
# Processing Record 28 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 5 | puerto ayacucho
# Processing Record 30 of Set 5 | bonavista
# Processing Record 31 of Set 5 | sinnamary
# Processing Record 32 of Set 5 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 5 | morondava
# Processing Record 34 of Set 5 | firozpur jhirka
# Processing Record 35 of Set 5 | los algarrobos
# Processing Record 36 of Set 5 | port antonio
# Processing Record 37 of Set 5 | wolmaranstad
# City not found. Skipping...
# Processing Record 38 of Set 5 | mecca
# Processing Record 39 of Set 5 | marystown
# Processing Record 40 of Set 5 | aripuana
# Processing Record 41 of Set 5 | los llanos de aridane
# Processing Record 42 of Set 5 | lokosovo
# Processing Record 43 of Set 5 | gat
# Processing Record 44 of Set 5 | johnson city
# Processing Record 45 of Set 5 | bengkulu
# Processing Record 46 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 47 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | gdov
# Processing Record 50 of Set 5 | ghanzi
# Processing Record 1 of Set 6 | macau
# Processing Record 2 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 6 | san rafael del sur
# Processing Record 4 of Set 6 | inhuma
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | kargopol
# Processing Record 7 of Set 6 | dubrovnik
# Processing Record 8 of Set 6 | hashtrud
# Processing Record 9 of Set 6 | moussoro
# Processing Record 10 of Set 6 | micheweni
# Processing Record 11 of Set 6 | tirumullaivasal
# Processing Record 12 of Set 6 | qandala
# Processing Record 13 of Set 6 | wadsworth
# Processing Record 14 of Set 6 | korla
# Processing Record 15 of Set 6 | calbuco
# Processing Record 16 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 6 | laguna
# Processing Record 18 of Set 6 | shush
# Processing Record 19 of Set 6 | kuybyshevo
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | plettenberg bay
# Processing Record 22 of Set 6 | acarau
# Processing Record 23 of Set 6 | vetralla
# Processing Record 24 of Set 6 | selma
# Processing Record 25 of Set 6 | havre-saint-pierre
# Processing Record 26 of Set 6 | iquique
# Processing Record 27 of Set 6 | filadelfia
# Processing Record 28 of Set 6 | waw
# Processing Record 29 of Set 6 | qaqortoq
# Processing Record 30 of Set 6 | mayor pablo lagerenza
# Processing Record 31 of Set 6 | havoysund
# Processing Record 32 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | tumaco
# Processing Record 35 of Set 6 | rostaq
# City not found. Skipping...
# Processing Record 36 of Set 6 | lisala
# Processing Record 37 of Set 6 | sur
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | skjervoy
# Processing Record 40 of Set 6 | pietermaritzburg
# Processing Record 41 of Set 6 | robertsport
# Processing Record 42 of Set 6 | isla mujeres
# Processing Record 43 of Set 6 | birjand
# Processing Record 44 of Set 6 | adrar
# Processing Record 45 of Set 6 | naryan-mar
# Processing Record 46 of Set 6 | goshen
# Processing Record 47 of Set 6 | grindavik
# Processing Record 48 of Set 6 | taltal
# Processing Record 49 of Set 6 | vila velha
# Processing Record 50 of Set 6 | labe
# Processing Record 1 of Set 7 | valdivia
# Processing Record 2 of Set 7 | vieques
# Processing Record 3 of Set 7 | huntington
# Processing Record 4 of Set 7 | saint-georges
# Processing Record 5 of Set 7 | luena
# Processing Record 6 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 7 | ruwi
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | bay roberts
# Processing Record 10 of Set 7 | aksarka
# Processing Record 11 of Set 7 | matara
# Processing Record 12 of Set 7 | quatre cocos
# Processing Record 13 of Set 7 | cervo
# Processing Record 14 of Set 7 | uruzgan
# Processing Record 15 of Set 7 | chuy
# Processing Record 16 of Set 7 | nizhnyaya tavda
# Processing Record 17 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 18 of Set 7 | joshimath
# Processing Record 19 of Set 7 | copiapo
# Processing Record 20 of Set 7 | opuwo
# Processing Record 21 of Set 7 | dingle
# Processing Record 22 of Set 7 | praia da vitoria
# Processing Record 23 of Set 7 | vestmannaeyjar
# Processing Record 24 of Set 7 | mizdah
# Processing Record 25 of Set 7 | wa
# City not found. Skipping...
# Processing Record 26 of Set 7 | emba
# Processing Record 27 of Set 7 | mezen
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | rocha
# Processing Record 30 of Set 7 | nebolchi
# Processing Record 31 of Set 7 | luanda
# Processing Record 32 of Set 7 | surt
# Processing Record 33 of Set 7 | den helder
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | mindelo
# Processing Record 36 of Set 7 | krasnoshchekovo
# Processing Record 37 of Set 7 | mitsamiouli
# Processing Record 38 of Set 7 | vila do maio
# Processing Record 39 of Set 7 | aksu
# Processing Record 40 of Set 7 | saint-joseph
# Processing Record 41 of Set 7 | thompson
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | iranshahr
# Processing Record 44 of Set 7 | virginia beach
# Processing Record 45 of Set 7 | senador guiomard
# Processing Record 46 of Set 7 | burica
# City not found. Skipping...
# Processing Record 47 of Set 7 | novobelokatay
# Processing Record 48 of Set 7 | bakau
# Processing Record 49 of Set 7 | longavi
# Processing Record 50 of Set 7 | okitipupa
# Processing Record 1 of Set 8 | pedernales
# Processing Record 2 of Set 8 | tsabong
# Processing Record 3 of Set 8 | rajpipla
# Processing Record 4 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 8 | bulawayo
# Processing Record 6 of Set 8 | mzimba
# Processing Record 7 of Set 8 | kuytun
# Processing Record 8 of Set 8 | penzance
# Processing Record 9 of Set 8 | liverpool
# Processing Record 10 of Set 8 | merritt island
# Processing Record 11 of Set 8 | lubao
# Processing Record 12 of Set 8 | guider
# Processing Record 13 of Set 8 | puerto baquerizo moreno
# Processing Record 14 of Set 8 | saint-louis
# Processing Record 15 of Set 8 | kedrovyy
# Processing Record 16 of Set 8 | quelimane
# Processing Record 17 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 8 | marsa matruh
# Processing Record 19 of Set 8 | roald
# Processing Record 20 of Set 8 | villamontes
# Processing Record 21 of Set 8 | zavoronezhskoye
# Processing Record 22 of Set 8 | nanticoke
# Processing Record 23 of Set 8 | rawson
# Processing Record 24 of Set 8 | oktyabrskoye
# Processing Record 25 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 8 | kattivakkam
# Processing Record 27 of Set 8 | ormara
# Processing Record 28 of Set 8 | moose factory
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | kralendijk
# Processing Record 31 of Set 8 | kyzyl-suu
# Processing Record 32 of Set 8 | anloga
# Processing Record 33 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 8 | tingi
# Processing Record 35 of Set 8 | araouane
# Processing Record 36 of Set 8 | nanortalik
# Processing Record 37 of Set 8 | kamenka
# Processing Record 38 of Set 8 | lucea
# Processing Record 39 of Set 8 | raga
# Processing Record 40 of Set 8 | anori
# Processing Record 41 of Set 8 | jijiga
# Processing Record 42 of Set 8 | uyuni
# Processing Record 43 of Set 8 | kumluca
# Processing Record 44 of Set 8 | tarko-sale
# Processing Record 45 of Set 8 | skibbereen
# Processing Record 46 of Set 8 | priekule
# Processing Record 47 of Set 8 | beyneu
# Processing Record 48 of Set 8 | murgab
# Processing Record 49 of Set 8 | muriti
# Processing Record 50 of Set 8 | omboue
# Processing Record 1 of Set 9 | sumbe
# Processing Record 2 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 3 of Set 9 | san ignacio
# Processing Record 4 of Set 9 | tvoroyri
# Processing Record 5 of Set 9 | libreville
# Processing Record 6 of Set 9 | ankazoabo
# Processing Record 7 of Set 9 | bosaso
# Processing Record 8 of Set 9 | cabedelo
# Processing Record 9 of Set 9 | praia
# Processing Record 10 of Set 9 | berbera
# Processing Record 11 of Set 9 | maicao
# Processing Record 12 of Set 9 | tessalit
# Processing Record 13 of Set 9 | rassvet
# Processing Record 14 of Set 9 | axim
# Processing Record 15 of Set 9 | san carlos de bariloche
# Processing Record 16 of Set 9 | annau
# Processing Record 17 of Set 9 | marsh harbour
# Processing Record 18 of Set 9 | ancud
# Processing Record 19 of Set 9 | peniche
# Processing Record 20 of Set 9 | trois-rivieres
# Processing Record 21 of Set 9 | parfino
# Processing Record 22 of Set 9 | parsabad
# Processing Record 23 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 25 of Set 9 | canutama
# Processing Record 26 of Set 9 | iqaluit
# Processing Record 27 of Set 9 | raudeberg
# Processing Record 28 of Set 9 | langangen
# City not found. Skipping...
# Processing Record 29 of Set 9 | la cruz
# Processing Record 30 of Set 9 | minab
# Processing Record 31 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 9 | port maria
# Processing Record 33 of Set 9 | saint-francois
# Processing Record 34 of Set 9 | leua
# Processing Record 35 of Set 9 | almonte
# Processing Record 36 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 9 | gopamau
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | le vauclin
# Processing Record 40 of Set 9 | mehran
# Processing Record 41 of Set 9 | shubarkuduk
# Processing Record 42 of Set 9 | kaberamaido
# Processing Record 43 of Set 9 | puerto carreno
# Processing Record 44 of Set 9 | fenoarivo
# Processing Record 45 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 9 | beamsville
# Processing Record 47 of Set 9 | yurkivka
# Processing Record 48 of Set 9 | longonjo
# Processing Record 49 of Set 9 | majdanpek
# Processing Record 50 of Set 9 | ilebo
# Processing Record 1 of Set 10 | la paz
# Processing Record 2 of Set 10 | savonlinna
# Processing Record 3 of Set 10 | aden
# Processing Record 4 of Set 10 | salta
# Processing Record 5 of Set 10 | mirnyy
# Processing Record 6 of Set 10 | novyy yegorlyk
# Processing Record 7 of Set 10 | la motte-servolex
# Processing Record 8 of Set 10 | korsakovo
# Processing Record 9 of Set 10 | meulaboh
# Processing Record 10 of Set 10 | batavia
# Processing Record 11 of Set 10 | zabol
# Processing Record 12 of Set 10 | lugoba
# Processing Record 13 of Set 10 | cumberland
# Processing Record 14 of Set 10 | mamlyutka
# Processing Record 15 of Set 10 | kingisepp
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | shabqadar
# Processing Record 18 of Set 10 | bryanka
# Processing Record 19 of Set 10 | santiago del estero
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | balkhash
# Processing Record 22 of Set 10 | sakakah
# Processing Record 23 of Set 10 | totma
# Processing Record 24 of Set 10 | bataipora
# Processing Record 25 of Set 10 | maniitsoq
# Processing Record 26 of Set 10 | beloha
# Processing Record 27 of Set 10 | ambilobe
# Processing Record 28 of Set 10 | tahta
# Processing Record 29 of Set 10 | contamana
# Processing Record 30 of Set 10 | bani
# Processing Record 31 of Set 10 | moa
# Processing Record 32 of Set 10 | bodden town
# Processing Record 33 of Set 10 | boca do acre
# Processing Record 34 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 35 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 10 | mangrol
# Processing Record 37 of Set 10 | diamantino
# Processing Record 38 of Set 10 | ipora
# Processing Record 39 of Set 10 | konevo
# Processing Record 40 of Set 10 | binga
# Processing Record 41 of Set 10 | dilla
# Processing Record 42 of Set 10 | bereda
# Processing Record 43 of Set 10 | krasnoselkup
# Processing Record 44 of Set 10 | nyrob
# Processing Record 45 of Set 10 | cairo montenotte
# Processing Record 46 of Set 10 | morros
# Processing Record 47 of Set 10 | bekovo
# Processing Record 48 of Set 10 | zile
# Processing Record 49 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 50 of Set 10 | syamzha
# Processing Record 1 of Set 11 | mahon
# Processing Record 2 of Set 11 | serenje
# Processing Record 3 of Set 11 | mbigou
# Processing Record 4 of Set 11 | suez
# Processing Record 5 of Set 11 | chadiza
# Processing Record 6 of Set 11 | ambovombe
# Processing Record 7 of Set 11 | glens falls
# Processing Record 8 of Set 11 | nyimba
# Processing Record 9 of Set 11 | pastavy
# Processing Record 10 of Set 11 | kaliyaganj
# Processing Record 11 of Set 11 | san pedro de macoris
# Processing Record 12 of Set 11 | bhongir
# Processing Record 13 of Set 11 | saint-pierre
# Processing Record 14 of Set 11 | kanye
# Processing Record 15 of Set 11 | natal
# Processing Record 16 of Set 11 | hassleholm
# Processing Record 17 of Set 11 | usinsk
# Processing Record 18 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 11 | diego de almagro
# Processing Record 20 of Set 11 | cayenne
# Processing Record 21 of Set 11 | marathon
# Processing Record 22 of Set 11 | rio gallegos
# Processing Record 23 of Set 11 | magugu
# Processing Record 24 of Set 11 | benjamin aceval
# Processing Record 25 of Set 11 | san ramon de la nueva oran
# Processing Record 26 of Set 11 | eydhafushi
# Processing Record 27 of Set 11 | chapais
# Processing Record 28 of Set 11 | taboga
# Processing Record 29 of Set 11 | taoudenni
# Processing Record 30 of Set 11 | kronach
# Processing Record 31 of Set 11 | ibra
# Processing Record 32 of Set 11 | salinopolis
# Processing Record 33 of Set 11 | ornskoldsvik
# Processing Record 34 of Set 11 | hualmay
# Processing Record 35 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 11 | langres
# Processing Record 37 of Set 11 | likasi
# Processing Record 38 of Set 11 | touros
# Processing Record 39 of Set 11 | sept-iles
# Processing Record 40 of Set 11 | kidal
# Processing Record 41 of Set 11 | chapleau
# Processing Record 42 of Set 11 | el alto
# Processing Record 43 of Set 11 | uribia
# Processing Record 44 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 45 of Set 11 | freeport
# Processing Record 46 of Set 11 | uppsala
# Processing Record 47 of Set 11 | ushtobe
# Processing Record 48 of Set 11 | mahajanga
# Processing Record 49 of Set 11 | cehegin
# Processing Record 50 of Set 11 | lolodorf
# Processing Record 1 of Set 12 | konibodom
# Processing Record 2 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 12 | mpika
# Processing Record 4 of Set 12 | vadgaon
# Processing Record 5 of Set 12 | illapel
# Processing Record 6 of Set 12 | bandarbeyla
# Processing Record 7 of Set 12 | santa cruz
# Processing Record 8 of Set 12 | summerside
# Processing Record 9 of Set 12 | agadez
# Processing Record 10 of Set 12 | la macarena
# Processing Record 11 of Set 12 | solwezi
# Processing Record 12 of Set 12 | ballina
# Processing Record 13 of Set 12 | sjenica
# Processing Record 14 of Set 12 | matay
# Processing Record 15 of Set 12 | dudinka
# Processing Record 16 of Set 12 | arlit
# Processing Record 17 of Set 12 | galle
# Processing Record 18 of Set 12 | mavrovi anovi
# Processing Record 19 of Set 12 | lyantonde
# Processing Record 20 of Set 12 | katihar
# Processing Record 21 of Set 12 | reconquista
# Processing Record 22 of Set 12 | tashtagol
# Processing Record 23 of Set 12 | nioro
# Processing Record 24 of Set 12 | paita
# Processing Record 25 of Set 12 | limbe
# Processing Record 26 of Set 12 | krosno odrzanskie
# Processing Record 27 of Set 12 | la palma
# Processing Record 28 of Set 12 | villarrica
# Processing Record 29 of Set 12 | denau
# City not found. Skipping...
# Processing Record 30 of Set 12 | bagli
# Processing Record 31 of Set 12 | inirida
# Processing Record 32 of Set 12 | kashi
# Processing Record 33 of Set 12 | tiznit
# Processing Record 34 of Set 12 | calamar
# Processing Record 35 of Set 12 | bocas del toro
# Processing Record 36 of Set 12 | santa maria
# Processing Record 37 of Set 12 | malanje
# Processing Record 38 of Set 12 | itaituba
# Processing Record 39 of Set 12 | komsomolskiy
# Processing Record 40 of Set 12 | dire
# Processing Record 41 of Set 12 | stornoway
# Processing Record 42 of Set 12 | pocone
# Processing Record 43 of Set 12 | rosario
# Processing Record 44 of Set 12 | geraldton
# Processing Record 45 of Set 12 | tahoua
# Processing Record 46 of Set 12 | abu samrah
# Processing Record 47 of Set 12 | kavaratti
# Processing Record 48 of Set 12 | san andres
# Processing Record 49 of Set 12 | cartagena
# Processing Record 50 of Set 12 | aleysk
# Processing Record 1 of Set 13 | keetmanshoop
# Processing Record 2 of Set 13 | ciudad bolivar
# Processing Record 3 of Set 13 | forestville
# Processing Record 4 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 13 | mooi river
# City not found. Skipping...
# Processing Record 6 of Set 13 | saurimo
# Processing Record 7 of Set 13 | mabaruma
# Processing Record 8 of Set 13 | sao jose da coroa grande
# Processing Record 9 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 13 | novo aripuana
# Processing Record 11 of Set 13 | trojes
# Processing Record 12 of Set 13 | male
# Processing Record 13 of Set 13 | bibiani
# Processing Record 14 of Set 13 | tartus
# Processing Record 15 of Set 13 | prieska
# Processing Record 16 of Set 13 | medenychi
# Processing Record 17 of Set 13 | melfi
# Processing Record 18 of Set 13 | yambio
# Processing Record 19 of Set 13 | nantucket
# Processing Record 20 of Set 13 | zwedru
# Processing Record 21 of Set 13 | khash
# Processing Record 22 of Set 13 | malia
# Processing Record 23 of Set 13 | rundu
# Processing Record 24 of Set 13 | yar-sale
# Processing Record 25 of Set 13 | bitkine
# Processing Record 26 of Set 13 | santona
# Processing Record 27 of Set 13 | mana
# Processing Record 28 of Set 13 | sardarpur
# Processing Record 29 of Set 13 | rafaela
# Processing Record 30 of Set 13 | sioux lookout
# Processing Record 31 of Set 13 | el carmen
# Processing Record 32 of Set 13 | lugazi
# Processing Record 33 of Set 13 | okrika
# Processing Record 34 of Set 13 | sambava
# Processing Record 35 of Set 13 | znamenskoye
# Processing Record 36 of Set 13 | fort-shevchenko
# Processing Record 37 of Set 13 | sapernoye
# Processing Record 38 of Set 13 | zemio
# Processing Record 39 of Set 13 | turkistan
# Processing Record 40 of Set 13 | malakal
# Processing Record 41 of Set 13 | morant bay
# Processing Record 42 of Set 13 | teguldet
# Processing Record 43 of Set 13 | huarmey
# Processing Record 44 of Set 13 | ler
# Processing Record 45 of Set 13 | puerto madryn
# Processing Record 46 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | saint-remi
# Processing Record 48 of Set 13 | port said
# Processing Record 49 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 13 | hofn
# Processing Record 1 of Set 14 | sumbawanga
# Processing Record 2 of Set 14 | duz
# City not found. Skipping...
# Processing Record 3 of Set 14 | panyutyne
# Processing Record 4 of Set 14 | novaya zaimka
# Processing Record 5 of Set 14 | forio
# Processing Record 6 of Set 14 | saint-augustin
# Processing Record 7 of Set 14 | sovetskiy
# Processing Record 8 of Set 14 | shahrud
# Processing Record 9 of Set 14 | booue
# Processing Record 10 of Set 14 | saint-paul
# Processing Record 11 of Set 14 | necochea
# Processing Record 12 of Set 14 | rudnichnyy
# Processing Record 13 of Set 14 | sao gabriel
# Processing Record 14 of Set 14 | talara
# Processing Record 15 of Set 14 | kayes
# Processing Record 16 of Set 14 | kinna
# Processing Record 17 of Set 14 | rosarno
# Processing Record 18 of Set 14 | sibut
# Processing Record 19 of Set 14 | kichmengskiy gorodok
# Processing Record 20 of Set 14 | sehithwa
# Processing Record 21 of Set 14 | igarka
# Processing Record 22 of Set 14 | key biscayne
# Processing Record 23 of Set 14 | moroni
# Processing Record 24 of Set 14 | abu dhabi
# Processing Record 25 of Set 14 | mandera
# Processing Record 26 of Set 14 | kandhla
# Processing Record 27 of Set 14 | canoinhas
# Processing Record 28 of Set 14 | zhanakorgan
# Processing Record 29 of Set 14 | akkermanovka
# Processing Record 30 of Set 14 | neyshabur
# Processing Record 31 of Set 14 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 32 of Set 14 | eidsvag
# Processing Record 33 of Set 14 | mitu
# Processing Record 34 of Set 14 | itapaci
# Processing Record 35 of Set 14 | caconda
# Processing Record 36 of Set 14 | nurlat
# Processing Record 37 of Set 14 | dabat
# Processing Record 38 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 14 | boende
# Processing Record 40 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 41 of Set 14 | bayir
# Processing Record 42 of Set 14 | dinan
# Processing Record 43 of Set 14 | marrakesh
# Processing Record 44 of Set 14 | panama city
# Processing Record 45 of Set 14 | erzincan
# Processing Record 46 of Set 14 | seminole
# Processing Record 47 of Set 14 | alberton
# Processing Record 48 of Set 14 | san alberto
# Processing Record 49 of Set 14 | gunjur
# Processing Record 50 of Set 14 | olinda
# Processing Record 1 of Set 15 | garowe
# Processing Record 2 of Set 15 | verrettes
# Processing Record 3 of Set 15 | dombarovskiy
# Processing Record 4 of Set 15 | thinadhoo
# Processing Record 5 of Set 15 | el tigre
# Processing Record 6 of Set 15 | santa rosa
# Processing Record 7 of Set 15 | maamba
# Processing Record 8 of Set 15 | manaure
# Processing Record 9 of Set 15 | turtas
# Processing Record 10 of Set 15 | bertoua
# Processing Record 11 of Set 15 | atasu
# Processing Record 12 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 13 of Set 15 | bekhtery
# Processing Record 14 of Set 15 | keuruu
# Processing Record 15 of Set 15 | bogo
# Processing Record 16 of Set 15 | batsfjord
# Processing Record 17 of Set 15 | mikumi
# Processing Record 18 of Set 15 | suraabad
# Processing Record 19 of Set 15 | klyuchi
# Processing Record 20 of Set 15 | voyvozh
# Processing Record 21 of Set 15 | novodolinskiy
# Processing Record 22 of Set 15 | carquefou
# Processing Record 23 of Set 15 | port shepstone
# Processing Record 24 of Set 15 | hearst
# Processing Record 25 of Set 15 | usak
# Processing Record 26 of Set 15 | kamoke
# Processing Record 27 of Set 15 | uitenhage
# Processing Record 28 of Set 15 | french harbor
# Processing Record 29 of Set 15 | ratodero
# Processing Record 30 of Set 15 | tambura
# Processing Record 31 of Set 15 | garbovi
# Processing Record 32 of Set 15 | jiwani
# Processing Record 33 of Set 15 | iskateley
# Processing Record 34 of Set 15 | lima
# Processing Record 35 of Set 15 | mikhaylovka
# Processing Record 36 of Set 15 | brasilia
# Processing Record 37 of Set 15 | kita
# Processing Record 38 of Set 15 | kiruna
# Processing Record 39 of Set 15 | ugoofaaru
# Processing Record 40 of Set 15 | talah
# City not found. Skipping...
# Processing Record 41 of Set 15 | rotifunk
# Processing Record 42 of Set 15 | kibaya
# Processing Record 43 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 15 | saquarema
# Processing Record 45 of Set 15 | reggello
# Processing Record 46 of Set 15 | cerrito
# Processing Record 47 of Set 15 | chimbote
# Processing Record 48 of Set 15 | san luis
# Processing Record 49 of Set 15 | johi
# Processing Record 50 of Set 15 | yurino
# Processing Record 1 of Set 16 | coruripe
# Processing Record 2 of Set 16 | arica
# Processing Record 3 of Set 16 | marienburg
# Processing Record 4 of Set 16 | barcelos
# Processing Record 5 of Set 16 | madinat sittah uktubar
# Processing Record 6 of Set 16 | sorland
# Processing Record 7 of Set 16 | damaturu
# Processing Record 8 of Set 16 | bethanien
# Processing Record 9 of Set 16 | chancay
# Processing Record 10 of Set 16 | inta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             Ponta Do Sol  32.6667 -17.1000     65.12        67          80
# 1                 Manicore  -5.8092 -61.3003     82.35        78          20
# 2               Bredasdorp -34.5322  20.0403     62.37        69         100
# 3              Burlatskoye  45.0564  43.6350     36.14        93         100
# 4                Cape Town -33.9258  18.4232     71.38        58          40
# 5                 Tasiilaq  65.6145 -37.6368     22.75        95         100
# 6               Hambantota   6.1241  81.1185     79.14        89          20
# 7  Sao Geraldo Do Araguaia  -6.4006 -48.5550     83.75        70          76
# 8                      Van  38.4924  43.3831     29.55        93          75
# 9                     Juba   4.8517  31.5825     95.79        16          18
#
#    Wind Speed Country Current Description
# 0        5.59      PT          light rain
# 1        5.75      BR          few clouds
# 2       14.65      ZA     overcast clouds
# 3       13.76      RU     overcast clouds
# 4       27.63      ZA    scattered clouds
# 5        8.32      GL                snow
# 6        5.75      LK          few clouds
# 7        3.62      BR       broken clouds
# 8        3.44      TR                mist
# 9        8.34      SS          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                       City Country      Lat      Lng  Max Temp  Humidity  \
# 0             Ponta Do Sol      PT  32.6667 -17.1000     65.12        67
# 1                 Manicore      BR  -5.8092 -61.3003     82.35        78
# 2               Bredasdorp      ZA -34.5322  20.0403     62.37        69
# 3              Burlatskoye      RU  45.0564  43.6350     36.14        93
# 4                Cape Town      ZA -33.9258  18.4232     71.38        58
# 5                 Tasiilaq      GL  65.6145 -37.6368     22.75        95
# 6               Hambantota      LK   6.1241  81.1185     79.14        89
# 7  Sao Geraldo Do Araguaia      BR  -6.4006 -48.5550     83.75        70
# 8                      Van      TR  38.4924  43.3831     29.55        93
# 9                     Juba      SS   4.8517  31.5825     95.79        16
#
#    Cloudiness  Wind Speed Current Description
# 0          80        5.59          light rain
# 1          20        5.75          few clouds
# 2         100       14.65     overcast clouds
# 3         100       13.76     overcast clouds
# 4          40       27.63    scattered clouds
# 5         100        8.32                snow
# 6          20        5.75          few clouds
# 7          76        3.62       broken clouds
# 8          75        3.44                mist
# 9          18        8.34          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output, index_label="City_ID")
